# %%
import PyPDF2
import re
import pandas as pd
#import camelot
import camelot.io as camelot
# from Pylance import pymssql

import tabula
from tabula.io import read_pdf, convert_into, convert_into_by_batch
# specify the file path
file_path = "7K.pdf"

# extract all tables from the PDF file
tables = camelot.read_pdf(file_path, pages="all",flavor='stream')
tables
# Out:
# <TableList n=41>

# %%
tables[1].df
#tables[0].df.drop([0,1,2,3],axis=0,inplace=True)
# Out:
#             0            1                        2          3  \
# 0   3/16/2020
# 1    Tô, Trâm     CLEANDYE                 Chemical  Nhân Viên
# 2                  VIETNAM                            Mua Hàng
# 3                  COMPANY
# 4                  LIMITED
# ..        ...          ...                      ...        ...
# 84         Tú  INTEGRATION  Equipment Manufacturing
# 85                 COMPANY
# 86                 LIMITED
# 87  Vũ, Giang  CMD COMPANY          Channel Partner  Nhân viên
# 88                 LIMITED
#
#                                                4                5  \
# 0   My Contact ~ Salesforce - Enterprise Edition
# 1                                  +84-918781711    +84-931448643
# 2
# 3
# 4
# ..                                           ...              ...
# 84
# 85
# 86
# 87                                 +84-375555540  +84-167-5555540
# 88
#
#                             6      7   8
# 0
# 1        tram.to@cleandye.com   Trâm  Tô
# 2
# 3
# 4
# ..                        ...    ...  ..
# 84
# 85
# 86
# 87  vuhoanggiangvhg@gmail.com  Giang  Vũ
# 88
#
# [89 rows x 9 columns]
